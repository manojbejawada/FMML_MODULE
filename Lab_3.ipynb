# %% [markdown]
# <a href="https://colab.research.google.com/github/manojbejawada/FMML_MODULE/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 03:02:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   130MB/s    in 0.5s
#
# 2025-03-15 03:02:02 (130 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24853   1412.3709v2  Object class detectors typically apply a windo...    cs
# 22271  1511.03249v3  A method for large scale Gaussian process clas...  stat
# 35025  1511.02623v1  Living organisms survive and multiply even tho...    cs
# 23066  1803.03764v3  In this paper, we propose variance networks, a...  stat
# 7278   1711.06793v1  Additive models, such as produced by gradient ...  stat
# ...             ...                                                ...   ...
# 18390   1004.1772v1  Terrorism has led to many problems in Thai soc...    cs
# 11792  1701.05512v2  We introduce Fisher consistency in the sense o...  stat
# 22888  1710.01720v1  Uncertainty analysis in the form of probabilis...  stat
# 10683   1206.6487v1  We present a new anytime algorithm that achiev...    cs
# 6366   1611.07634v1  State of the art machine learning algorithms a...  stat
#
#                                                    title  year  \
# 24853  An active search strategy for efficient object...  2014
# 22271  Stochastic Expectation Propagation for Large S...  2015
# 35025       Toward Biochemical Probabilistic Computation  2015
# 23066  Variance Networks: When Expectation Does Not M...  2018
# 7278   Tree-Structured Boosting: Connections Between ...  2017
# ...                                                  ...   ...
# 18390  Terrorism Event Classification Using Fuzzy Inf...  2010
# 11792     Fisher consistency for prior probability shift  2017
# 22888  Smooth Pinball Neural Network for Probabilisti...  2017
# 10683  An Adaptive Algorithm for Finite Stochastic Pa...  2012
# 6366   Interpretation of Prediction Models Using the ...  2016
#
#                                                 keywords
# 24853  [detectors, typically, classifier, proposals, ...
# 22271  [classification, expectation, propagation, cla...
# 35025  [organisms, uncertain, incomplete, information...
# 23066  [information, variances, surprisingly, informa...
# 7278   [interaction, classification, regression, algo...
# ...                                                  ...
# 18390  [terrorism, societies, casualties, predicting,...
# 11792  [introduce, consistency, unbiasedness, desirab...
# 22888  [uncertainty, probabilistic, forecasting, sign...
# 10683  [algorithm, stochastic, monitoring, particular...
# 6366   [algorithms, optimized, prediction, naturally,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24853    [detectors, typically, classifier, proposals, ...
# 22271    [classification, expectation, propagation, cla...
# 35025    [organisms, uncertain, incomplete, information...
# 23066    [information, variances, surprisingly, informa...
# 7278     [interaction, classification, regression, algo...
#                                ...
# 40550    [optimization, parametric, overarching, princi...
# 27528    [automatic, extraction, selection, technique, ...
# 9968     [classification, fundamental, classification, ...
# 16578    [ensembling, technique, translation, performan...
# 27584    [introduce, inversefacenet, convolutional, ren...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8667 words.
# Out of those 4563 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e93dadb5-35f6-471a-aa04-43c7b6e3cc0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e93dadb5-35f6-471a-aa04-43c7b6e3cc0c")) {                    Plotly.newPlot(                        "e93dadb5-35f6-471a-aa04-43c7b6e3cc0c",                        [{"x":["promising","evaluations","efficient","challenging","classifier","observing","framework","experiments","detectors","independently","information","statistical","evaluating","efficiently","proposals","substantial","reduction","typically","appearance","sequentially","detection","surrounding","classifiers","classification","expectation","limitation","techniques","nevertheless","inference","stochastic","resources","competitive","instances","propagation","variational","cognitive","computation","biological","probability","fundamental","environment","appropriate","mechanisms","available","perceptive","successfully","imperfect","challenge","incomplete","signaling","functions","distributions","organisms","reasoning","interacting","assemblies","represent","consequences","biochemical","probabilistic","populations","uncertain","adversarial","surprisingly","numerical","criterion","intuitive","variables","ensembles","prediction","conventional","therefore","expectations","ensembling","curvature","determine","variances","application","implications","investigated","introduces","structured","predictive","revealing","connections","primarily","parameter","approaches","regression","isolation","applications","equivalent","technique","outperform","interaction","performance","represented","interpretability","algorithms","experimental","benchmarks","supported","recognition","introducing","significantly","predicted","localization","outstanding","extensive","supervised","supervision","encourages","discriminative","contrastive","boundaries","convolutional","evaluation","structures","commodity","redundancy","effectiveness","guaranteed","relationships","computing","independence","maximally","demonstrated","computationally","phenotypes","introduce","deployment","expression","platforms","selection","dimensionality","specifically","sophisticated","implemented","nonlinear","dimensional","ubiquitous","algorithm","satisfies","observation","frobenius","summarize","estimation","truncated","multiplicative","incoherence","completion","approximation","interesting","covariance","statistics","gathering","bottleneck","automatic","disambiguation","wikipedia","automatically","increasingly","constructed","currently","annotated","knowledge","acquisition","proliferation","overcoming","important","advancement","languages","constraints","conjunction","eliminates","problematic","solutions","eliminate","propagating","generating","tractability","symmetric","effective","generators","polynomial","considers","generator","symmetries","favorably","coordination","furthermore","monitoring","asynchronous","developing","challenges","continues","distributed","autonomous","alternating","structural"],"y":[110,56,427,297,156,22,542,635,34,35,669,165,51,161,30,48,92,109,69,16,336,19,126,497,24,28,358,19,228,118,79,116,100,72,53,53,170,42,171,88,132,74,53,305,2,64,10,162,32,4,215,118,4,123,16,1,121,12,1,156,13,24,91,28,90,42,42,112,14,222,110,140,9,6,7,64,9,250,20,50,70,103,54,7,43,13,118,452,121,4,453,53,240,111,87,873,77,22,559,374,100,20,346,47,262,35,82,18,180,196,52,9,99,12,32,410,249,150,7,25,215,28,73,122,25,11,91,101,0,354,16,46,28,174,52,158,31,109,63,179,21,834,15,44,2,23,202,12,15,3,24,117,85,20,60,7,16,198,13,22,182,48,66,60,66,327,37,5,8,363,6,94,155,21,10,10,139,8,8,124,6,19,249,11,65,49,32,4,22,9,160,34,7,70,115,8,95,65,26,62],"type":"bar"},{"x":["promising","evaluations","efficient","challenging","classifier","observing" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4563,), (4563, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8208333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>scale</span> <span style=''>Image</span> <span style=''>Fusion</span> <span style=''>Between</span> <span style=''>Pre</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>operative</span> <span style=''>Clinical</span> <span style=''>CT</span> <span style=''>and</span> <span style=''>X</span> <span style=''>ray</span> <span style=''>Microtomography</span> <span style=''>of</span> <span style=''>Lung</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Pathology</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Computational</span> <span style=''>anatomy</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.48936170212765956);'>quantitative</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>organs</span> <span style=''>in</span> <span style=''>medical</span> <span style=''>images</span> <span style=''>However</span> <span style=''>most</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>millimeter</span> <span style=''>scale</span> <span style=''>because</span> <span style=''>of</span> <span style=''>the</span> <span style=''>limited</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>resolution</span> <span style=''>of</span> <span style=''>clinical</span> <span style=''>computed</span> <span style='background-color:rgba(0, 255, 0, 0.3548387096774195);'>tomography</span> <span style=''>(CT)</span> <span style=''>X</span> <span style=''>ray</span> <span style=''>microtomography</span> <span style=''>(muCT)</span> <span style=''>on</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>allows</span> <span style=''>imaging</span> <span style=''>of</span> <span style=''>ex</span> <span style=''>vivo</span> <span style=''>tissues</span> <span style=''>at</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>resolution</span> <span style=''>of</span> <span style=''>tens</span> <span style=''>of</span> <span style=''>microns</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>use</span> <span style=''>clinical</span> <span style=''>CT</span> <span style=''>to</span> <span style=''>image</span> <span style=''>lung</span> <span style=''>cancer</span> <span style=''>patients</span> <span style=''>before</span> <span style=''>partial</span> <span style=''>pneumonectomy</span> <span style=''>(resection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>pathological</span> <span style=''>lung</span> <span style=''>tissue)</span> <span style=''>The</span> <span style=''>resected</span> <span style=''>specimen</span> <span style=''>is</span> <span style=''>prepared</span> <span style=''>for</span> <span style=''>muCT</span> <span style=''>imaging</span> <span style=''>at</span> <span style=''>a</span> <span style=''>voxel</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>resolution</span> <span style=''>of</span> <span style=''>50</span> <span style=''>mum</span> <span style=''>(005</span> <span style=''>mm)</span> <span style=''>This</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>resolution</span> <span style=''>image</span> <span style=''>of</span> <span style=''>the</span> <span style=''>lung</span> <span style=''>cancer</span> <span style=''>tissue</span> <span style=''>allows</span> <span style=''>further</span> <span style=''>insides</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3281853281853281);'>understanding</span> <span style=''>of</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Iteratively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reweighted</span> <span style=''>Least</span> <span style=''>Squares</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>L1</span> <span style=''>Norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>(PCA)</span> <span style=''>is</span> <span style=''>often</span> <span style=''>used</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>data</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>few</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthonormal</span> <span style=''>vectors</span> <span style=''>that</span> <span style=''>explain</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>L1</span> <span style=''>PCA</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>L1</span> <span style=''>norm</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>error</span> <span style=''>whereas</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>PCA</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>L2</span> <span style=''>norm</span> <span style=''>For</span> <span style=''>the</span> <span style=''>L1</span> <span style=''>PCA</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style=''>fitting</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructed</span> <span style=''>data</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reweighted</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteratively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reweighted</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>We</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>analyses</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>against</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>Coordinate</span> <span style=''>Descent</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>arises</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>solvable</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>but</span> <span style=''>general</span> <span style=''>purpose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>high</span> <span style=''>running</span> <span style=''>times</span> <span style=''>and</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsuitable</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>have</span> <span style=''>used</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>sums</span> <span style=''>of</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>use</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>coordinate</span> <span style=''>descent</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>faster</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.33534743202416917);'>convergence</span> <span style=''>rates</span> <span style=''>and</span> <span style=''>cheaper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>costs</span> <span style=''>Compared</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>methods</span> <span style=''>our</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminative</span> <span style=''>Metric</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Deep</span> <span style=''>Forest</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminative</span> <span style=''>Deep</span> <span style=''>Forest</span> <span style=''>(DisDF)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>paper</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Deep</span> <span style=''>Forest</span> <span style=''>or</span> <span style=''>gcForest</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Zhou</span> <span style=''>and</span> <span style=''>Feng</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>gcForest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modification</span> <span style=''>The</span> <span style=''>case</span> <span style=''>of</span> <span style=''>the</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>studied</span> <span style=''>when</span> <span style=''>the</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>training</span> <span style=''>examples</span> <span style=''>are</span> <span style=''>known</span> <span style=''>The</span> <span style=''>main</span> <span style=''>idea</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>to</span> <span style=''>assign</span> <span style=''>weights</span> <span style=''>to</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>in</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>reduce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>between</span> <span style=''>objects</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style=''>class</span> <span style=''>and</span> <span style=''>to</span> <span style=''>increase</span> <span style=''>them</span> <span style=''>between</span> <span style=''>objects</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>classes</span> <span style=''>The</span> <span style=''>weights</span> <span style=''>are</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>A</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>which</span> <span style=''>combines</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Manhattan</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplifies</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08419921175206019)
# 	information (0.23969903260480116)
# 	challenging (0.10641347187388032)
# 	representation (0.13256897169473308)
# 	experimental (0.13400214976710856)
# 	segmentation (0.07130060910068076)
# 	different (0.2511644571838051)
# 	detection (0.12038695807954139)
# 	recognition (0.12396990326048012)
# 	convolutional (0.146900752418488)
#
# Some Statistics words are:
# 	algorithm (0.3797909407665505)
# 	stochastic (0.12991538078646092)
# 	statistical (0.1483325037332006)
# 	theoretical (0.1523145843703335)
# 	estimation (0.17073170731707318)
# 	distribution (0.18068690890990544)
# 	variables (0.14584370333499252)
# 	inference (0.19263315082130414)
# 	dimensional (0.18964659034345446)
# 	regression (0.16923842707814835)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="88932009-a5cc-4d46-a4c9-6cd0284739d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88932009-a5cc-4d46-a4c9-6cd0284739d7")) {                    Plotly.newPlot(                        "88932009-a5cc-4d46-a4c9-6cd0284739d7",                        [{"x":["promising","evaluations","efficient","challenging","classifier","observing","framework","experiments","detectors","independently","information","statistical","evaluating","efficiently","proposals","substantial","reduction","typically","appearance","sequentially","detection","surrounding","classifiers","classification","expectation","limitation","techniques","nevertheless","inference","stochastic","resources","competitive","instances","propagation","variational","cognitive","computation","biological","probability","fundamental","environment","appropriate","mechanisms","available","perceptive","successfully","imperfect","challenge","incomplete","signaling","functions","distributions","organisms","reasoning","interacting","assemblies","represent","consequences","biochemical","probabilistic","populations","uncertain","adversarial","surprisingly","numerical","criterion","intuitive","variables","ensembles","prediction","conventional","therefore","expectations","ensembling","curvature","determine","variances","application","implications","investigated","introduces","structured","predictive","revealing","connections","primarily","parameter","approaches","regression","isolation","applications","equivalent","technique","outperform","interaction","performance","represented","interpretability","algorithms","experimental","benchmarks","supported","recognition","introducing","significantly","predicted","localization","outstanding","extensive","supervised","supervision","encourages","discriminative","contrastive","boundaries","convolutional","evaluation","structures","commodity","redundancy","effectiveness","guaranteed","relationships","computing","independence","maximally","demonstrated","computationally","phenotypes","introduce","deployment","expression","platforms","selection","dimensionality","specifically","sophisticated","implemented","nonlinear","dimensional","ubiquitous","algorithm","satisfies","observation","frobenius","summarize","estimation","truncated","multiplicative","incoherence","completion","approximation","interesting","covariance","statistics","gathering","bottleneck","automatic","disambiguation","wikipedia","automatically","increasingly","constructed","currently","annotated","knowledge","acquisition","proliferation","overcoming","important","advancement","languages","constraints","conjunction","eliminates","problematic","solutions","eliminate","propagating","generating","tractability","symmetric","effective","generators","polynomial","considers","generator","symmetries","favorably","coordination","furthermore","monitoring","asynchronous","developing","challenges","continues","distributed","autonomous","alternating","structural","traditional","heuristics","understood","objective","understanding","accurately","convergence","significant","projected","properties","optimization","workaround","relaxation","procedures","especially","frequently","literature","minimization","practitioner","comparably","interpreted","factorization","computational","dirichlet","allocation","consumption","documents","extracting","containing","complexity","increasing","undersampling","procedure","implements","inferring","statistically","association","resulting","outperforms","scenarios","illustrate","analyzing","shrinkage","estimator","simplicity","backpropagation","demonstrate","transforming","rendering","considered","mathematical","substantially","including","decreases","construction","dif ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	phenotypes
# 	exposition
# 	orthogonality
# 	diagonalise
# 	nullspace
# 	certifiable
# 	functoriality
# 	kleinberg
# 	statisticians
# 	archetypes
# 	factoring
# 	trilinear
# 	unregularized
# 	subexponential
# 	prominently
# 	realisation
# 	sequencing
# 	depression
# 	blackwellized
# 	robustification
# Some words which never appear in Statistics papers:
# 	perceptive
# 	evidenced
# 	fortunately
# 	neuromorphic
# 	synchronize
# 	uncalibrated
# 	utterance
# 	precomputed
# 	illuminated
# 	photometric
# 	retrieves
# 	beamforming
# 	processable
# 	enriching
# 	pragmatics
# 	repetitive
# 	granulation
# 	punctuation
# 	gazetteer
# 	hypernymy

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079481415329658e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7808333333333334
